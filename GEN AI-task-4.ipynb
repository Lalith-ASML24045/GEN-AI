# %%
# %pip uninstall transformers -y
# %pip install transformers==4.57.6 sentencepiece
# Out:
# Found existing installation: transformers 4.57.6
# Uninstalling transformers-4.57.6:
#   Successfully uninstalled transformers-4.57.6
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformers==4.57.6
#   Using cached transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: sentencepiece in c:\users\hp\anaconda3\lib\site-packages (0.2.2)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (3.32.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (2026.7.19)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hp\anaconda3\lib\site-packages (from transformers==4.57.6) (4.70.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (2026.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (4.16.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.57.6) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers==4.57.6) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers==4.57.6) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers==4.57.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers==4.57.6) (2026.7.22)
# Using cached transformers-4.57.6-py3-none-any.whl (12.0 MB)
# Installing collected packages: transformers
# Successfully installed transformers-4.57.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformers
from transformers.pipelines import PIPELINE_REGISTRY

print("Transformers version:", transformers.__version__)
print("Summarization available:",
      "summarization" in PIPELINE_REGISTRY.get_supported_tasks())
# Out:
# Transformers version: 4.57.6
# Summarization available: True

# %%
from transformers import pipeline

summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn"
)

print("Model loaded successfully!")
# Out:
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# C:\Users\Hp\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Hp\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Device set to use cpu
# Model loaded successfully!

# %%
text = """
Artificial intelligence has become one of the most influential technologies
in the modern world. It is being used in many areas such as healthcare,
education, transportation, banking, agriculture, and entertainment.
Artificial intelligence enables machines to perform tasks that normally
require human intelligence, including learning, problem-solving,
decision-making, and understanding language. In healthcare, AI systems can
assist doctors in identifying diseases and analyzing medical images. In
education, AI-powered applications can provide personalized learning
experiences based on the needs of individual students. Businesses use AI to
analyze large amounts of data, understand customer behavior, and improve
their services. Self-driving vehicles also use artificial intelligence to
identify objects, understand road conditions, and make driving decisions.
Despite these advantages, artificial intelligence also creates several
challenges. Issues such as data privacy, algorithmic bias, job displacement,
security, and the responsible use of AI have become important concerns.
Developers and organizations must ensure that artificial intelligence
systems are transparent, fair, reliable, and safe. Governments and
researchers are also working to create guidelines for the responsible
development of AI technologies. As artificial intelligence continues to
advance, it is expected to become even more integrated into everyday life.
Therefore, understanding both the benefits and risks of AI is important for
ensuring that the technology contributes positively to society.
"""

# %%
summary_result = summarizer(
    text,
    max_length=80,
    min_length=30,
    do_sample=False
)

summary = summary_result[0]["summary_text"]

print("Generated Summary:")
print(summary)
# Out:
# Generated Summary:
# Artificial intelligence enables machines to perform tasks that normally require human intelligence. Issues such as data privacy, algorithmic bias, job displacement, and responsible use of AI have become important concerns. As artificial intelligence continues to advance, it is expected to become even more integrated into everyday life.

# %%
original_word_count = len(text.split())
summary_word_count = len(summary.split())

print("Original Word Count :", original_word_count)
print("Summary Word Count  :", summary_word_count)
# Out:
# Original Word Count : 208
# Summary Word Count  : 47
