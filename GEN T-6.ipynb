# %%
import sys
import torch
import transformers

print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
# Out:
# Python: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# PyTorch: 2.13.0+cpu
# Transformers: 4.57.6

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

print("BLIP libraries are working!")
# Out:
# BLIP libraries are working!

# %%
processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Hp\sem_5_projects\Generative AI

# %%
Image.open("dog.jfif")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x365>

# %%
image = Image.open("dog.jfif").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a puppy running through a field

# %%
Image.open("bird.jfif")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=679x450>

# %%
image = Image.open("bird.jfif").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a bird perched on a branch

# %%
Image.open("car.jfif")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x320>

# %%
image = Image.open("car.jfif").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a black suv with a white background
